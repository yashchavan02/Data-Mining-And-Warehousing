# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Person': ['A', 'B', 'C'],
    'Age': [30, 50, None],
    'Sal': [20000, 80000, 30000]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Person   Age    Sal
# 0      A  30.0  20000
# 1      B  50.0  80000
# 2      C   NaN  30000

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df
# Out:
#   Person   Age    Sal
# 0      A  30.0  20000
# 1      B  50.0  80000
# 2      C  40.0  30000

# %%
minAge = df['Age'].min()
maxAge = df['Age'].max()

ageScalingFactor = maxAge - minAge

df['Age'] = (df['Age'] - minAge) / ageScalingFactor

# %%
df
# Out:
#   Person  Age    Sal
# 0      A  0.0  20000
# 1      B  1.0  80000
# 2      C  0.5  30000

# %%
minSal = df['Sal'].min()
maxSal = df['Sal'].max()

salScalingFactor = maxSal - minSal

df['Sal'] = round((df['Sal'] - minSal) / salScalingFactor, 1)

# %%
df
# Out:
#   Person  Age  Sal
# 0      A  0.0  0.0
# 1      B  1.0  1.0
# 2      C  0.5  0.2

# %%
df2 = pd.read_csv(r'/content/ev.csv')

# %%
df2.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# 1  Electronic Card Transactions (ANZSIC06) - ECT
# 2  Electronic Card Transactions (ANZSIC06) - ECT
# 3  Electronic Card Transactions (ANZSIC06) - ECT
# 4  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                Group Series_title_1  \
# 0  Total values - Electronic card transactions A/...         Actual
# ...

# %%
df2.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df2.drop('Suppressed', axis=1, inplace=True)

# %%
df2.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'STATUS', 'UNITS',
#        'Magnitude', 'Subject', 'Group', 'Series_title_1', 'Series_title_2',
#        'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df2.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value           1989
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3      16174
# Series_title_4      20124
# Series_title_5      20124
# dtype: int64

# %%
df2.shape
# Out:
# (20124, 13)

# %%
df2.drop(['Series_title_3', 'Series_title_4', 'Series_title_5'], axis=1, inplace=True)

# %%
df2
# Out:
#       Series_reference   Period  Data_value STATUS    UNITS  Magnitude  \
# 0           ECTA.S19A1  2001.03      2462.5      F  Dollars          6
# 1           ECTA.S19A1  2002.03     17177.2      F  Dollars          6
# 2           ECTA.S19A1  2003.03     22530.5      F  Dollars          6
# 3           ECTA.S19A1  2004.03     28005.1      F  Dollars          6
# 4           ECTA.S19A1  2005.03     30629.6      F  Dollars          6
# ...                ...      ...         ...    ...      ...        ...
# 20119       ECTQ.S4AXP  2022.12        32.7      F  Percent          0
# 20120       ECTQ.S4AXP  2023.03        31.9      F  Percent          0
# 20121       ECTQ.S4AXP  2023.06        33.0      F  Percent          0
# 20122       ECTQ.S4AXP  2023.09        33.2      F  Percent          0
# 20123       ECTQ.S4AXP  2023.12        32.7      F  Percent          0
#
#                                              Subject  \
# 0      Electronic Card Transactions (ANZSIC06) - ECT
# ...

# %%
df2.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'STATUS', 'UNITS',
#        'Magnitude', 'Subject', 'Group', 'Series_title_1', 'Series_title_2'],
#       dtype='object')

# %%
df2.isnull().sum()
# Out:
# Series_reference       0
# Period                 0
# Data_value          1989
# STATUS                 0
# UNITS                  0
# Magnitude              0
# Subject                0
# Group                  0
# Series_title_1         0
# Series_title_2         0
# dtype: int64

# %%
minDataValue = df2['Data_value'].mean()

# %%
df2['Data_value'] = df2['Data_value'].fillna(minDataValue)

# %%
df2.sample(3)
# Out:
#       Series_reference   Period   Data_value STATUS    UNITS  Magnitude  \
# 5646        ECTM.S19TW  2010.01       2029.5      R  Dollars          6
# 12648       ECTM.S29A1  2016.02  104674806.0      F   Number          0
# 14980       ECTM.S4AXP  2020.06         38.9      F  Percent          0
#
#                                              Subject  \
# 5646   Electronic Card Transactions (ANZSIC06) - ECT
# 12648  Electronic Card Transactions (ANZSIC06) - ECT
# 14980  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                    Group Series_title_1  \
# 5646   Total values - Electronic card transactions A/...          Trend
# 12648  Number of electronic card transactions A/S/T b...         Actual
# 14980  Electronic card transactions by mean and propo...         Actual
#
#                                           Series_title_2
# 5646                                              Credit
# ...
