# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = [
    ['Milk', 'Bread', 'Butter'],
    ['Bread', 'Butter', 'Jam'],
    ['Milk', 'Bread'],
    ['Milk', 'Bread', 'Butter', 'Jam'],
    ['Milk', 'Bread', 'Butter'],
    ['Bread', 'Butter'],
    ['Milk', 'Bread', 'Butter'],
    ['Milk', 'Apple'],
    ['Milk', 'Bread', 'Apple'],
    ['Milk', 'Bread', 'Butter', 'Jam']
]

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
print(df.head())
# Out:
#    Apple  Bread  Butter    Jam   Milk
# 0  False   True    True  False   True
# 1  False   True    True   True  False
# 2  False   True   False  False   True
# 3  False   True    True   True   True
# 4  False   True    True  False   True

# %%
frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)

# %%
frequent_itemsets
# Out:
#    support               itemsets
# 0      0.9                (Bread)
# 1      0.7               (Butter)
# 2      0.8                 (Milk)
# 3      0.7        (Bread, Butter)
# 4      0.7          (Bread, Milk)
# 5      0.5         (Butter, Milk)
# 6      0.5  (Bread, Butter, Milk)

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

# %%
print(rules[['antecedents','consequents','support','confidence','lift']])
# Out:
#         antecedents      consequents  support  confidence      lift
# 0           (Bread)         (Butter)      0.7    0.777778  1.111111
# 1          (Butter)          (Bread)      0.7    1.000000  1.111111
# 2           (Bread)           (Milk)      0.7    0.777778  0.972222
# 3            (Milk)          (Bread)      0.7    0.875000  0.972222
# 4          (Butter)           (Milk)      0.5    0.714286  0.892857
# 5            (Milk)         (Butter)      0.5    0.625000  0.892857
# 6   (Bread, Butter)           (Milk)      0.5    0.714286  0.892857
# 7     (Bread, Milk)         (Butter)      0.5    0.714286  1.020408
# 8    (Butter, Milk)          (Bread)      0.5    1.000000  1.111111
# 9          (Butter)    (Bread, Milk)      0.5    0.714286  1.020408
# 10           (Milk)  (Bread, Butter)      0.5    0.625000  0.892857
